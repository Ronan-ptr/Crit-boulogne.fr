# %% [markdown]
# ## EXTRACTION
# OBJECTIVE : Merge all tab of Recrutment file in on page csv

# %%
# TOOLS IMPORT
import pandas as pd # Main tool to manipulate data

hired = pd.read_excel("/home/prime/Projets/2026_PROJECT-DA/DATA/RECRUTEMENT.xlsx")

# %%
tab = hired.sheets_names

print(f"we find {tab} tab on the sheet")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_52570/3054722496.py in ?()
# ----> 1 tab = hired.sheets_names
#       2
#       3 print(f"we find {tab} tab on the sheet")
#
# ~/Projets/2026_PROJECT-DA/DATA_CLEAN/wiper/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sheets_names'
